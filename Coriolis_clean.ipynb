# %%
from manim import *
import numpy as np
from sympy import symbols, cos, sin, pi, lambdify, diff, Matrix
from sympy.vector import CoordSys3D, gradient, curl
import sympy as S

# %% [markdown]
# <center> <strong>Basic Wave Equation </strong></center>
#
# $$
# \begin{align*}
# P(x) &= A\sin{\left(\frac{2\pi}{\lambda} \left( x + \nu t\right) + \phi\right)} \\
# \text{where...}\\
# P(x) &= \text{Pressure (defined only by an x coordinate)}\\
# A &= \text{Amplitude}\\
# \lambda &= \text{Wavelength}\\
# x &= \text{Position along the x axis}\\
# \text{and...}\\
# \nu &= f\lambda\\
# f &= \text{frequency} = \frac{1}{T}\\
# T &= \text{period}\\
# t &= \text{time}\\
# \end{align*}
# $$

# %%
t, v, A, lamda, phi, omega, Omega = S.symbols('t, v, A, lamda, phi, omega, Omega' )

a = 5
lamma = 10
phi_value = 0
seconds_in_day = T=  24*60*60
omega=2*PI/seconds_in_day

substitutions_list = [(A, a),(Omega, omega),(lamda, lamma), (phi, phi_value)]

# %%
#lets define some pressure field only based on the x axis


#first we define a coordinate system
N = CoordSys3D('N')
N.x
# Out:
# N.x

# %%
#interesting... lets try
N.i
# Out:
# N.i

# %% [markdown]
# Cool, so 'N.x' gives us the magnitude of the basis vector in the x direction. 'N.i' gives us the base vector

# %% [markdown]
# Let's define a spherical coordinate system 'B' to be compatible with N

# %%
v_e = 3
v_i = 10
v_n = 4
v_u = 0

# %%
Omega = omega*cos(phi)*N.j + omega*sin(phi)*N.k
v = v_e*N.i + v_n*N.j + v_u*N.k
v
# Out:
# 3*N.i + 4*N.j

# %%
Omega
# Out:
# (7.27220521664304e-5*cos(phi))*N.j + (7.27220521664304e-5*sin(phi))*N.k

# %%
-Omega.cross(v)
# Out:
# (0.000290888208665722*sin(phi))*N.i + (-0.000218166156499291*sin(phi))*N.j + (0.000218166156499291*cos(phi))*N.k

# %%
B = N.create_new('B', transformation='spherical')
B
# Out:
# B

# %%
B.i
# Out:
# B.i

# %%
N.i.dot(B.i)
# Out:
# 1

# %%
B.k
# Out:
# B.k

# %%
B.z
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 B.z
#
# AttributeError: 'CoordSys3D' object has no attribute 'z'

# %%
B.theta, B.phi
# Out:
# (B.theta, B.phi)

# %%
rho = Matrix([[0],[2*S.pi/seconds_in_day],[0]])
type(rho)
# Out:
# sympy.matrices.dense.MutableDenseMatrix

# %% [markdown]
# lets define a velocity field with this x,y,z coordinate system

# %%
turd_velocity_field = N.x*N.i + N.y*N.j
turd_cori_acc = -Omega.cross(turd_velocity_field)
turd_eval = turd_cori_acc.subs(substitutions_list)
turd_matrix = turd_eval.to_matrix(N)
turd_matrix
# Out:
# Matrix([
# [                      0],
# [                      0],
# [7.27220521664304e-5*N.x]])

# %%
turd_func= lambdify((N.x, N.y), turd_matrix, 'numpy')

# %%
def give_manim_goodies(sympy_vector_field, subs_list, coords): #coords should be N or whatever the base coordinate system is
    manim_string = S.latex(sympy_vector_field).replace('}}', '} }'). replace('{{', '{ {')
    evaluated_vec_field = sympy_vector_field.subs(substitutions_list)
    vec_field_as_matrix = evaluated_vec_field.to_matrix(coords)
    vec_field_as_func = lambdify((N.x, N.y), vec_field_as_matrix, 'numpy')

    return (manim_string, vec_field_as_func)

def coriolis_force(velocity_field):
    Omega = omega*cos(phi)*N.j + omega*sin(phi)*N.k
    return -2*Omega.cross(velocity_field)

# %%
velocity_field = (A*sin(N.x*2*S.pi/lamda)+v_i)*N.i + N.x/lamda*N.j 
velocity_field
# Out:
# (A*sin(2*N.x*pi/lamda) + 10)*N.i + N.x/lamda*N.j

# %%
coriolis_force(velocity_field)
# Out:
# (0.000145444104332861*N.x*sin(phi)/lamda)*N.i + (-0.000145444104332861*(A*sin(2*N.x*pi/lamda) + 10)*sin(phi))*N.j + (-2*(-7.27220521664304e-5*A*sin(2*N.x*pi/lamda) - 0.000727220521664304)*cos(phi))*N.k

# %%
give_manim_goodies(coriolis_force(turd_velocity_field), substitutions_list, N)[1]
# Out:
# <function _lambdifygenerated(Dummy_15425, Dummy_15424)>

# %%
coriolis_acceleration = -Omega.cross(velocity_field)
2*coriolis_acceleration
# Out:
# (0.000145444104332861*N.x*sin(phi)/lamda)*N.i + (-0.000145444104332861*(A*sin(2*N.x*pi/lamda) + 10)*sin(phi))*N.j + (-2*(-7.27220521664304e-5*A*sin(2*N.x*pi/lamda) - 0.000727220521664304)*cos(phi))*N.k

# %%
substitutions_list
# Out:
# [(A, 5), (Omega, 7.27220521664304e-05), (lamda, 10), (phi, 0)]

# %%
phi_value = S.pi/4
substitutions_list[3]=(phi, phi_value)
substitutions_list

coriolis_eval = coriolis_acceleration.subs(substitutions_list)
coriolis_eval
# Out:
# (3.63610260832152e-6*sqrt(2)*N.x)*N.i + (sqrt(2)*(-0.000363610260832152*sin(N.x*pi/5) - 0.000727220521664304)/2)*N.j + (sqrt(2)*(0.000363610260832152*sin(N.x*pi/5) + 0.000727220521664304)/2)*N.k

# %%
coriolis_acceleration_latex_spaced = S.latex(coriolis_acceleration).replace('}}', '} }'). replace('{{', '{ {')

# %%
cori_in_the_house = coriolis_eval.to_matrix(N)
cori_in_the_house
# Out:
# Matrix([
# [                                       3.63610260832152e-6*sqrt(2)*N.x],
# [sqrt(2)*(-0.000363610260832152*sin(N.x*pi/5) - 0.000727220521664304)/2],
# [ sqrt(2)*(0.000363610260832152*sin(N.x*pi/5) + 0.000727220521664304)/2]])

# %%
cori_in_the_house[0]
# Out:
# 3.63610260832152e-6*sqrt(2)*N.x

# %%
coriolis_vector_func = lambdify((N.x, N.y), cori_in_the_house, 'numpy')
coriolis_vector_func
# Out:
# <function _lambdifygenerated(Dummy_15427, Dummy_15426)>

# %%
pressure_gradient_function([array,array])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 pressure_gradient_function([array,array])
#
# NameError: name 'pressure_gradient_function' is not defined

# %%
field_equation_latex
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 field_equation_latex
#
# NameError: name 'field_equation_latex' is not defined

# %%
coriolis_vector_func(0,0).flatten()
# Out:
# array([ 0.        , -0.00051422,  0.00051422])

# %%
substitutions_list
# Out:
# [(A, 5), (Omega, 7.27220521664304e-05), (lamda, 10), (phi, pi/4)]

# %%
# %%manim -qm -v  WARNING Coriolis_field
# class Coriolis_field(MovingCameraScene):
#     def construct(self):
#
#         # def dot_position(mobject):
#         #     mobject.set_value(dot.get_center()[0])
#         #     mobject.next_to(dot)
#         domain = np.array([[-15, 15, 0.5],[-15, 15, 0.5],[-10, 10, 1]])
#
#         # print(np.min(domain[0]))
#         field_1_function = give_manim_goodies(turd_velocity_field, substitutions_list, N)
#         field_2_function = give_manim_goodies(coriolis_force(turd_velocity_field), substitutions_list, N)
#
#         print(type(field_1_function))
#         # x_var = Variable(np.min(domain[0]), 'x', num_decimal_places=3)
#         equations_mobject = MathTex(field_1_function[0] +'\\'+ field_2_function[0]).to_corner(UL)
#         self.add(equations_mobject)
#         # field_function = Variable(np.min(domain[0]), equation, num_decimal_places=3).next_to(x_var, RIGHT)
#
#
#
#         # self.add_fixed_in_frame_mobjects(text)
#
#
#         first_arrow_field_function = lambda pos: func= field_1_function[1](pos[0], pos[1]).flatten()
#         # domain = np.array([[-15, 15, 1],[-10, 10, 1],[-40, 40, 0.5]])
#         coriolis_vector_field = ArrowVectorField(first_arrow_field_function,
#                                   x_range= [-15,15,1],
#                                   y_range= [-15,15,1])
#         second_arrow_field_function = lambda pos: func= field_2_function[1](pos[0], pos[1]).flatten()
#         velocity_vector_field = ArrowVectorField(second_arrow_field_function,
#                                   x_range= [-15,15,1],
#                                   y_range= [-15,15,1])
#         # sets dot at bottom left of screen
#         # dot = Dot().move_to([np.minimum(domain[0]), np.minimum(domain[1]),0]to
#
#
#         # field_function.add_updater(lambda v: v.tracker.set_value(func([x_var.tracker.get_value(),0])[0]))
#         #keeps the equation handy
#
#         #the thing we want
#         self.add(coriolis_vector_field, velocity_vector_field)
#
#
#         # self.play(self.camera.auto_zoom(vector_field, margin=1), run_time=0.5)
#         # text = VGroup(x_var, field_function)
#         # text.scale(0.75).to_corner(UL)
#
#         # self.play(self.camera.set_zoom(self.camera.get_zoom()*0.25), runtime=5)
#         # self.camera.set_zoom(.5)
#         # frame = self.camera
#
#
#
#         # dot = Dot().move_to(RIGHT*(np.min(domain[0])))
#         # self.play(Create(dot))
#         # dot.add_updater(lambda d: d.next_to(x_var.tracker.get_value()*RIGHT, UP))
#
#
#
#         # self.play(x_var.tracker.animate.set_value(5), run_time=10, rate_func=linear)
#
#         # dot = Dot()
#         # self.add()
#
#         # self.play(MoveToTarget(equation)
#         # self.wait(2)
# Out:
# Traceback (most recent call last):
#
#   File ~\miniconda3\envs\python_jupyter_env\lib\site-packages\IPython\core\interactiveshell.py:3526 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[40], line 1
#     get_ipython().run_cell_magic('manim', '-qm -v WARNING Coriolis_field', "class Coriolis_field(MovingCameraScene):\n    def construct(self):\n\n        # def dot_position(mobject):\n        #     mobject.set_value(dot.get_center()[0])\n        #     mobject.next_to(dot)\n        domain = np.array([[-15, 15, 0.5],[-15, 15, 0.5],[-10, 10, 1]])\n        \n        # print(np.min(domain[0]))\n        field_1_function = give_manim_goodies(turd_velocity_field, substitutions_list, N)\n        field_2_function = give_manim_goodies(coriolis_force(turd_velocity_field), substitutions_list, N)\n\n        print(type(field_1_function))\n        # x_var = Variable(np.min(domain[0]), 'x', num_decimal_places=3)\n        equations_mobject = MathTex(field_1_function[0] +'\\\\'+ field_2_function[0]).to_corner(UL)\n        self.add(equations_mobject)\n        # field_function = Variable(np.min(domain[0]), equation, num_decimal_places=3).next_to(x_var, RIGHT)\n\n        \n\n        # self.add_fixed_in_frame_mobjects(text)\n        \n       \n        first_arrow_field_function = lambda pos: func= field_1_function[1](pos[0], pos[1]).flatten()\n        # domain = np.array([[-15, 15, 1],[-10, 10, 1],[-40, 40, 0.5]])\n        coriolis_vector_field = ArrowVectorField(first_arrow_field_function, \n                                  x_range= [-15,15,1],\n                                  y_range= [-15,15,1])\n        second_arrow_field_function = lambda pos: func= field_2_function[1](pos[0], pos[1]).flatten()\n        velocity_vector_field = ArrowVectorField(second_arrow_field_function, \n                                  x_range= [-15,15,1],\n                                  y_range= [-15,15,1])\n        # sets dot at bottom left of screen\n        # dot = Dot().move_to([np.minimum(domain[0]), np.minimum(domain[1]),0]to\n        \n        \n        # field_function.add_updater(lambda v: v.tracker.set_value(func([x_var.tracker.get_value(),0])[0]))\n        #keeps the equation handy\n        \n        #the thing we want\n        self.add(coriolis_vector_field, velocity_vector_field)\n        \n        \n        # self.play(self.camera.auto_zoom(vector_field, margin=1), run_time=0.5)\n        # text = VGroup(x_var, field_function)\n        # text.scale(0.75).to_corner(UL)\n        \n        # self.play(self.camera.set_zoom(self.camera.get_zoom()*0.25), runtime=5)\n        # self.camera.set_zoom(.5)\n        # frame = self.camera\n        \n    \n        \n        # dot = Dot().move_to(RIGHT*(np.min(domain[0])))\n        # self.play(Create(dot))\n        # dot.add_updater(lambda d: d.next_to(x_var.tracker.get_value()*RIGHT, UP))\n\n\n        \n        # self.play(x_var.tracker.animate.set_value(5), run_time=10, rate_func=linear)\n\n        # dot = Dot()\n        # self.add()\n        \n        # self.play(MoveToTarget(equation)\n        # self.wait(2)\n        \n        \n")
#
#   File ~\miniconda3\envs\python_jupyter_env\lib\site-packages\IPython\core\interactiveshell.py:2493 in run_cell_magic
#     result = fn(*args, **kwargs)
#
#   File ~\miniconda3\envs\python_jupyter_env\lib\site-packages\manim\utils\ipython_magic.py:120 in manim
#     exec(cell, local_ns)
#
#   File <string>:24
#     first_arrow_field_function = lambda pos: func= field_1_function[1](pos[0], pos[1]).flatten()
#                                  ^
# SyntaxError: cannot assign to lambda

# %%
# %load_ext line_profiler
# %prun Coriolis_field().construct()
# Out:
#          41143868 function calls (35939973 primitive calls) in 75.870 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 3651800/682262    3.356    0.000    3.953    0.000 traversal.py:119(_preorder_traversal)
#    109554    3.309    0.000    7.102    0.000 facts.py:599(deduce_all_facts)
# 5950760/5933462    2.320    0.000    2.402    0.000 {built-in method builtins.isinstance}
# 686154/641948    1.881    0.000   12.144    0.000 cache.py:69(wrapper)
# 71114/59582    1.874    0.000    7.428    0.000 basisdependent.py:238(__new__)
#    361336    1.662    0.000    3.410    0.000 sympify.py:101(sympify)
#     59551    1.578    0.000    1.578    0.000 bezier.py:54(<lambda>)
#   2139186    1.450    0.000    1.818    0.000 facts.py:633(<genexpr>)
# 124930/21142    1.227    0.000   21.762    0.001 printer.py:294(_print)
#   2330430    1.158    0.000    1.366    0.000 {built-in method builtins.hasattr}
#    126852    1.083    0.000    2.265    0.000 repmatrix.py:673(_getitem_RepMatrix)
# 123008/1922    1.060    0.000    3.235    0.002 lambdify.py:1295(_imp_namespace)
#   1138855    1.021    0.000    1.190    0.000 {built-in method builtins.getattr}
#    776490    0.886    0.000    2.681    0.000 {built-in method builtins.all}
#    101866    0.794    0.000    1.616    0.000 numbers.py:1372(__eq__)
#     28830    0.783    0.000    5.977    0.000 basic.py:559(<setcomp>)
# 138384/11532    0.769    0.000    7.853    0.001 basic.py:1233(_xreplace)
# 1116682/147994    0.757    0.000    0.859    0.000 traversal.py:252(postorder_traversal)
#    315208    0.696    0.000    1.594    0.000 basic.py:386(__eq__)
#      5766    0.695    0.000    5.681    0.001 mul.py:197(flatten)
#    799552    0.667    0.000    0.667    0.000 facts.py:582(_tell)
#   2058464    0.650    0.000    0.674    0.000 {method 'get' of 'dict' objects}
#     13454    0.640    0.000    5.998    0.000 basisdependent.py:190(__new__)
#      1922    0.635    0.000    0.635    0.000 {built-in method builtins.compile}
#     94178    0.612    0.000    3.839    0.000 assumptions.py:469(__init__)
# 893730/876432    0.607    0.000    0.754    0.000 basic.py:189(__hash__)
#   1485706    0.576    0.000    0.576    0.000 basic.py:786(args)
#    144098    0.550    0.000    0.550    0.000 {built-in method numpy.array}
# 221030/92256    0.538    0.000    9.183    0.000 decorators.py:99(binary_op_wrapper)
#      9611    0.528    0.000    0.683    0.000 function_base.py:24(linspace)
#    251782    0.509    0.000    2.667    0.000 sympify.py:502(_sympify)
#    699608    0.476    0.000    4.425    0.000 {built-in method builtins.next}
#    666934    0.476    0.000    4.884    0.000 traversal.py:162(__next__)
#    130696    0.459    0.000    2.577    0.000 numbers.py:2205(__mul__)
# 205654/67270    0.451    0.000    8.222    0.000 decorators.py:58(__sympifyit_wrapper)
# 147994/124930    0.446    0.000    4.060    0.000 decorators.py:224(_func)
#    171058    0.446    0.000    0.450    0.000 {method 'update' of 'set' objects}
#    132618    0.405    0.000    5.685    0.000 precedence.py:118(precedence)
#     99944    0.403    0.000    0.601    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#     34535    0.397    0.000    0.720    0.000 linalg.py:2383(norm)
#     17298    0.376    0.000    0.968    0.000 libmpf.py:1205(to_str)
# 28830/1922    0.376    0.000    5.616    0.003 vector.py:528(cross)
#     48076    0.369    0.000    0.369    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     40362    0.354    0.000    1.729    0.000 numbers.py:1405(_Frel)
#      9610    0.350    0.000   12.013    0.001 codeprinter.py:119(doprint)
#    126852    0.334    0.000    0.334    0.000 sdm.py:80(getitem)
#     23077    0.314    0.000    1.760    0.000 vectorized_mobject.py:175(generate_rgbas_array)
#     17298    0.300    0.000    1.529    0.000 latex.py:309(_needs_mul_brackets)
#    113398    0.300    0.000    0.393    0.000 basic.py:162(__new__)
#      1922    0.299    0.000   42.448    0.022 lambdify.py:181(lambdify)
#    342116    0.298    0.000    0.411    0.000 numbers.py:2289(__hash__)
#     51894    0.292    0.000    0.516    0.000 operations.py:108(_from_args)
#     30752    0.284    0.000    3.415    0.000 mul.py:182(__neg__)
#     38440    0.280    0.000    0.352    0.000 numbers.py:149(mpf_norm)
# 111476/13454    0.280    0.000    0.879    0.000 basic.py:1635(walk)
#    128774    0.278    0.000    0.464    0.000 numbers.py:808(__hash__)
# 40362/5766    0.276    0.000    0.813    0.000 vector.py:576(dot)
#     17298    0.267    0.000    0.555    0.000 libmpf.py:1153(to_digits_exp)
#      9608    0.260    0.000    0.260    0.000 {built-in method from_rotvec}
#      7688    0.251    0.000    0.635    0.000 matrices.py:888(_handle_creation_inputs)
#    740314    0.248    0.000    0.248    0.000 {built-in method builtins.len}
# 15376/3844    0.247    0.000    0.469    0.000 sorting.py:10(default_sort_key)
#      5766    0.247    0.000    6.393    0.001 operations.py:52(__new__)
#    126852    0.244    0.000    2.509    0.000 repmatrix.py:232(__getitem__)
#      1922    0.243    0.000   19.766    0.010 lambdify.py:1183(_preprocess)
# 71114/59582    0.242    0.000    7.629    0.000 vector.py:432(__new__)
#     86492    0.242    0.000    1.144    0.000 {built-in method builtins.any}
#      5766    0.239    0.000    4.449    0.001 str.py:261(_print_Mul)
#     30752    0.224    0.000    0.435    0.000 printer.py:258(__init__)
#      5766    0.224    0.000    3.795    0.001 latex.py:538(convert_args)
#    105710    0.221    0.000    7.174    0.000 assumptions.py:497(getit)
# 46128/23064    0.220    0.000    9.315    0.000 str.py:34(parenthesize)
#     24986    0.215    0.000    5.558    0.000 _print_helpers.py:27(__str__)
#     11532    0.214    0.000    0.394    0.000 latex.py:2898(translate)
#     69192    0.212    0.000    1.776    0.000 numbers.py:1739(__mul__)
#     99944    0.208    0.000    0.749    0.000 expr.py:215(__mul__)
#     65348    0.207    0.000    0.275    0.000 basic.py:367(_do_eq_sympify)
#     76880    0.207    0.000    0.542    0.000 numbers.py:1466(__hash__)
#     23077    0.207    0.000    2.084    0.000 vectorized_mobject.py:197(update_rgbas_array)
#     48050    0.206    0.000    0.214    0.000 libmpf.py:884(python_mpf_mul)
#      5766    0.204    0.000    4.493    0.001 codeprinter.py:512(_print_Mul)
#     28830    0.202    0.000    6.292    0.000 basic.py:485(atoms)
#     37482    0.202    0.000    0.202    0.000 {method 'update' of 'dict' objects}
# 376712/336350    0.200    0.000    0.302    0.000 {built-in method builtins.hash}
#     28830    0.198    0.000    4.244    0.000 mul.py:176(could_extract_minus_sign)
#     19220    0.197    0.000    0.431    0.000 sdm.py:70(__init__)
#     17298    0.197    0.000    0.580    0.000 numbers.py:1037(__new__)
#     38440    0.197    0.000    0.689    0.000 numbers.py:1181(_new)
#    147994    0.194    0.000    0.398    0.000 iterables.py:3076(is_sequence)
#     23077    0.189    0.000    0.274    0.000 iterables.py:166(make_even)
#    480555    0.183    0.000    0.183    0.000 {method 'append' of 'list' objects}
#      5766    0.178    0.000    5.550    0.001 latex.py:517(_print_Mul)
#      6729    0.176    0.000    1.438    0.000 mobject.py:1353(apply_points_function_about_point)
#      7688    0.176    0.000    0.861    0.000 repmatrix.py:127(_flat_list_to_DomainMatrix)
#     13454    0.173    0.000    1.809    0.000 basic.py:1411(replace)
#      7688    0.171    0.000    0.307    0.000 basic.py:2109(_aresame)
#     13466    0.165    0.000    0.165    0.000 bezier.py:237(interpolate)
#     46154    0.164    0.000    0.190    0.000 iterables.py:388(tuplify)
#     15325    0.164    0.000    0.458    0.000 space_ops.py:350(normalize)
#     23077    0.164    0.000    0.787    0.000 color.py:463(color_to_rgba)
#     37504    0.159    0.000    0.462    0.000 fromnumeric.py:71(_wrapreduction)
#     24986    0.158    0.000    1.282    0.000 {method 'sort' of 'list' objects}
# 73036/3844    0.157    0.000    0.256    0.000 sorting.py:168(_node_count)
#     24986    0.155    0.000    0.644    0.000 numbers.py:1275(__neg__)
# 11532/3844    0.153    0.000    0.532    0.000 sorting.py:179(_nodes)
#     63426    0.152    0.000    1.017    0.000 numbers.py:738(__mul__)
# 20188/17305    0.152    0.000    0.292    0.000 mobject.py:2167(get_family)
# 17298/5766    0.149    0.000    1.233    0.000 sorting.py:202(ordered)
#    111476    0.148    0.000    0.310    0.000 basic.py:1656(rec_replace)
#     17298    0.147    0.000    2.116    0.000 expr.py:1279(args_cnc)
#     15376    0.147    0.000    4.647    0.000 assumptions.py:509(_ask)
#     34459    0.146    0.000    0.287    0.000 {built-in method builtins.sorted}
#     13464    0.146    0.000    0.237    0.000 colour.py:370(rgb2hsl)
#    362338    0.145    0.000    0.145    0.000 {method 'items' of 'dict' objects}
#    115320    0.144    0.000    0.182    0.000 domain.py:821(__eq__)
# 30752/9610    0.140    0.000    0.761    0.000 basic.py:1641(<listcomp>)
# 63474/21158    0.140    0.000    0.876    0.000 colour.py:1003(__setattr__)
#     28772    0.137    0.000    0.137    0.000 {method 'dot' of 'numpy.ndarray' objects}
#      3844    0.137    0.000    0.137    0.000 {method 'split' of 're.Pattern' objects}
#     11532    0.135    0.000    0.279    0.000 mul.py:467(_gather)
#     55738    0.133    0.000    0.248    0.000 iterables.py:3018(iterable)
#     51894    0.133    0.000    0.785    0.000 mul.py:2086(<lambda>)
#      5766    0.132    0.000    0.226    0.000 basic.py:2007(_exec_constructor_postprocessors)
#      7688    0.132    0.000    2.406    0.000 immutable.py:104(_new)
#    103788    0.132    0.000    0.289    0.000 domain.py:825(__ne__)
#      9608    0.131    0.000    0.798    0.000 space_ops.py:246(rotation_matrix)
#      7688    0.129    0.000    0.770    0.000 immutable.py:120(_fromrep)
#      1876    0.129    0.000    0.347    0.000 numeric.py:1468(cross)
#      5763    0.127    0.000    2.453    0.000 vectorized_mobject.py:1131(get_nth_curve_length_pieces)
#     11532    0.126    0.000    0.881    0.000 str.py:737(_print_Float)
#      5766    0.126    0.000    0.361    0.000 radsimp.py:1043(fraction)
#     61504    0.126    0.000    0.126    0.000 libmpf.py:153(_normalize)
#    171058    0.125    0.000    0.125    0.000 {method 'copy' of 'dict' objects}
#     80724    0.122    0.000    0.180    0.000 <frozen importlib._bootstrap>:398(parent)
#     14430    0.121    0.000    0.556    0.000 mobject.py:1903(get_extremum_along_dim)
#     87482    0.120    0.000    0.120    0.000 {built-in method builtins.max}
#      6726    0.120    0.000    0.723    0.000 space_ops.py:171(rotate_vector)
#     40362    0.120    0.000    1.866    0.000 numbers.py:1450(__lt__)
# 26908/15376    0.119    0.000   13.558    0.001 printer.py:371(__call__)
#     21152    0.118    0.000    0.151    0.000 iterables.py:223(remove_list_redundancies)
#    142243    0.117    0.000    0.117    0.000 {built-in method __new__ of type object at 0x00007FF9E903E830}
#     11532    0.115    0.000    0.197    0.000 conventions.py:13(split_super_sub)
#     51894    0.114    0.000    0.243    0.000 numbers.py:1975(__hash__)
#      5763    0.114    0.000    1.636    0.000 vectorized_mobject.py:1154(<listcomp>)
#     28834    0.112    0.000    0.112    0.000 {method 'format' of 'str' objects}
#     30752    0.111    0.000    0.160    0.000 printer.py:250(_get_initial_settings)
#      1922    0.109    0.000   63.413    0.033 <string>:21(<lambda>)
#     24986    0.109    0.000    5.235    0.000 str.py:980(sstr)
#     17298    0.108    0.000    0.515    0.000 precedence.py:160(precedence_traditional)
#     51894    0.108    0.000    0.170    0.000 integerring.py:53(to_sympy)
#     94178    0.107    0.000    0.107    0.000 facts.py:579(__init__)
#      3844    0.107    0.000    0.146    0.000 textwrap.py:233(_wrap_chunks)
#     24981    0.105    0.000    0.146    0.000 mobject.py:617(__getattr__)
#      1922    0.104    0.000    0.934    0.000 basic.py:838(subs)
#      1922    0.101    0.000    0.960    0.000 lambdify.py:1419(_too_large_for_docstring)
#     17298    0.100    0.000    3.109    0.000 mul.py:2072(as_ordered_factors)
#     98022    0.099    0.000    0.154    0.000 libmpf.py:330(from_int)
#    105729    0.099    0.000    0.099    0.000 {method 'startswith' of 'str' objects}
#     49972    0.099    0.000    0.143    0.000 libmpf.py:574(mpf_cmp)
# 26908/15376    0.098    0.000   13.125    0.001 printer.py:290(doprint)
#      1922    0.098    0.000    8.410    0.004 latex.py:746(_print_BasisDependent)
#     49972    0.098    0.000    0.241    0.000 libmpf.py:626(mpf_lt)
#    128774    0.096    0.000    0.096    0.000 immutable.py:58(shape)
# 78801/5765    0.095    0.000    0.448    0.000 {built-in method builtins.sum}
#      7688    0.093    0.000    0.137    0.000 pycode.py:122(_module_format)
#      9610    0.093    0.000    0.129    0.000 ctx_mp_python.py:47(__new__)
#     28830    0.091    0.000    1.383    0.000 precedence.py:79(precedence_Float)
#     55738    0.090    0.000    0.143    0.000 numbers.py:2243(__eq__)
#     51894    0.089    0.000    0.259    0.000 repmatrix.py:754(<listcomp>)
#    169136    0.089    0.000    0.089    0.000 inspect.py:488(getmro)
#     13454    0.089    0.000    3.274    0.000 basisdependent.py:221(<listcomp>)
#      7688    0.089    0.000    0.333    0.000 symbol.py:298(__xnew__)
#      4810    0.089    0.000    1.010    0.000 mobject.py:1914(get_critical_point)
#      5766    0.088    0.000    0.975    0.000 latex.py:925(_print_Function)
#     11532    0.086    0.000    0.689    0.000 latex.py:1629(_deal_with_super_sub)
#     36518    0.086    0.000    3.573    0.000 basisdependent.py:43(__mul__)
#      3844    0.084    0.000    5.965    0.002 symbol.py:130(uniquely_named_symbol)
#      4810    0.084    0.000    0.153    0.000 vectorized_mobject.py:1395(get_anchors)
# 11532/7688    0.083    0.000    6.369    0.001 basic.py:313(fromiter)
#      9608    0.083    0.000    0.083    0.000 {method 'as_matrix' of 'scipy.spatial.transform._rotation.Rotation' objects}
#     44206    0.082    0.000    0.082    0.000 traversal.py:115(__init__)
#     32674    0.081    0.000    0.233    0.000 sympify.py:67(_is_numpy_instance)
#     17298    0.081    0.000    0.081    0.000 libintmath.py:131(bin_to_radix)
#     71129    0.081    0.000    0.091    0.000 {method 'join' of 'str' objects}
#     23082    0.081    0.000    0.561    0.000 color.py:454(color_to_rgb)
#     19220    0.081    0.000    0.109    0.000 domainmatrix.py:187(from_rep)
#    144162    0.080    0.000    0.080    0.000 {method 'endswith' of 'str' objects}
#      7688    0.080    0.000    0.479    0.000 repmatrix.py:101(_dod_to_DomainMatrix)
#     11532    0.079    0.000    0.209    0.000 mul.py:826(as_coeff_Mul)
#     13463    0.078    0.000    0.137    0.000 colour.py:272(hsl2rgb)
#      5766    0.077    0.000    0.367    0.000 pycode.py:334(_hprint_Pow)
#      5766    0.077    0.000    4.326    0.001 latex.py:522(convert)
#      1922    0.076    0.000   29.624    0.015 lambdify.py:1123(doprint)
#      9610    0.075    0.000    0.507    0.000 numbers.py:1294(__mul__)
#    149916    0.075    0.000    0.075    0.000 {built-in method builtins.divmod}
#     98022    0.075    0.000    0.075    0.000 sympify.py:73(<genexpr>)
#      5766    0.075    0.000    9.074    0.002 common.py:1931(<listcomp>)
#     26908    0.074    0.000    4.185    0.000 basisdependent.py:48(__rmul__)
#    111476    0.074    0.000    0.162    0.000 basic.py:1583(<lambda>)
#     11532    0.074    0.000    0.417    0.000 sdm.py:207(copy)
# 14423/9618    0.073    0.000    1.282    0.000 vectorized_mobject.py:267(set_stroke)
#      3844    0.073    0.000    0.159    0.000 pycode.py:99(__init__)
#      7688    0.072    0.000    0.082    0.000 sdm.py:309(to_list_flat)
#      5628    0.071    0.000    0.192    0.000 numeric.py:1393(moveaxis)
#     49989    0.071    0.000    0.071    0.000 {built-in method builtins.min}
#       960    0.071    0.000    1.407    0.001 mobject.py:1665(put_start_and_end_on)
#    159251    0.069    0.000    0.069    0.000 {built-in method _operator.index}
#      1922    0.069    0.000   53.695    0.028 1136875544.py:1(give_manim_goodies)
#      4810    0.068    0.000    0.353    0.000 vectorized_mobject.py:1409(get_points_defining_boundary)
#     17298    0.067    0.000    0.128    0.000 libmpf.py:59(prec_to_dps)
#    178746    0.067    0.000    0.067    0.000 basic.py:112(__sympy__)
#     17298    0.067    0.000    0.067    0.000 {method 'search' of 're.Pattern' objects}
#       961    0.066    0.000   75.392    0.078 vector_field.py:603(get_vector)
#      3844    0.066    0.000    2.845    0.001 symbol.py:197(<listcomp>)
#      1922    0.066    0.000    9.445    0.005 1136875544.py:9(coriolis_force)
#      7688    0.066    0.000    0.327    0.000 domainmatrix.py:105(__new__)
#      3850    0.065    0.000    0.069    0.000 function_base.py:5562(append)
# 89374/83608    0.064    0.000    0.078    0.000 {built-in method builtins.iter}
#    121086    0.064    0.000    0.064    0.000 vector.py:37(components)
#      3844    0.063    0.000    9.605    0.002 lambdify.py:1226(_subexpr)
#     30752    0.063    0.000    0.260    0.000 expr.py:200(__radd__)
#     46128    0.062    0.000    0.409    0.000 latex.py:335(<genexpr>)
#      2882    0.062    0.000    0.063    0.000 mobject.py:1227(<lambda>)
#     13463    0.061    0.000    0.288    0.000 colour.py:1023(get_rgb)
#     11256    0.061    0.000    0.091    0.000 numeric.py:1330(normalize_axis_tuple)
#     76880    0.060    0.000    0.060    0.000 sdm.py:77(<genexpr>)
#     34596    0.060    0.000    0.060    0.000 {built-in method math.log}
#     13454    0.060    0.000    0.121    0.000 libmpf.py:291(from_man_exp)
#    123008    0.059    0.000    0.059    0.000 basic.py:760(func)
#      5764    0.058    0.000    0.512    0.000 arc.py:262(get_length)
#      1922    0.058    0.000    2.319    0.001 vector.py:310(separate)
#     11532    0.058    0.000    0.609    0.000 domainmatrix.py:438(convert_to)
#     80724    0.058    0.000    0.058    0.000 {method 'rpartition' of 'str' objects}
#      7694    0.057    0.000    0.227    0.000 colour.py:617(web2hex)
#      1922    0.057    0.000    5.019    0.003 matrices.py:814(__str__)
#     76880    0.057    0.000    0.057    0.000 sdm.py:75(<genexpr>)
#      7694    0.056    0.000    0.103    0.000 colour.py:533(hex2rgb)
#     19222    0.056    0.000    0.056    0.000 {method 'match' of 're.Pattern' objects}
#     23077    0.056    0.000    0.843    0.000 vectorized_mobject.py:186(<listcomp>)
#     23064    0.055    0.000    3.839    0.000 precedence.py:61(precedence_Mul)
#      3844    0.055    0.000    0.274    0.000 symbol.py:446(__new__)
#     13464    0.055    0.000    0.055    0.000 colour.py:433(<listcomp>)
#     11532    0.054    0.000    0.114    0.000 iterables.py:579(sift)
#      5763    0.054    0.000    2.691    0.000 vectorized_mobject.py:1184(get_nth_curve_function_with_length)
#      5766    0.054    0.000    0.245    0.000 numbers.py:1922(_Rrel)
#      5766    0.053    0.000   10.818    0.002 common.py:1930(_eval_applyfunc)
#      9610    0.053    0.000    2.581    0.000 codeprinter.py:115(_handle_UnevaluatedExpr)
#     13454    0.053    0.000    6.051    0.000 vector.py:410(__new__)
#      9610    0.053    0.000    0.387    0.000 numbers.py:1255(_eval_is_extended_negative)
#    163405    0.052    0.000    0.052    0.000 {method 'lower' of 'str' objects}
#     34596    0.052    0.000    0.225    0.000 latex.py:332(<genexpr>)
#      3844    0.051    0.000    2.673    0.001 symbol.py:198(<listcomp>)
#      7694    0.051    0.000    0.946    0.000 colour.py:975(__init__)
#       961    0.051    0.000    2.690    0.003 arc.py:154(position_tip)
#     17298    0.051    0.000    0.083    0.000 str.py:270(<genexpr>)
#      5766    0.050    0.000    0.145    0.000 str.py:607(_print_Pow)
#     11532    0.050    0.000    0.072    0.000 sdm.py:223(<dictcomp>)
#      5766    0.050    0.000    0.425    0.000 latex.py:459(_print_Float)
#      1922    0.050    0.000    0.158    0.000 numpy.py:45(__init__)
#      2883    0.050    0.000    0.157    0.000 mobject.py:1141(shift)
#      5766    0.049    0.000    0.870    0.000 vector.py:70(dot)
#      9610    0.049    0.000    0.098    0.000 pycode.py:564(_print_Symbol)
#      9619    0.049    0.000    0.127    0.000 color.py:479(hex_to_rgb)
#     37504    0.049    0.000    0.049    0.000 fromnumeric.py:72(<dictcomp>)
#     13463    0.049    0.000    0.090    0.000 colour.py:995(__getattr__)
#      9610    0.048    0.000    0.144    0.000 ctx_mp_python.py:169(_cmp)
#     11532    0.048    0.000    0.491    0.000 sdm.py:574(convert_to)
#     17208    0.048    0.000    0.048    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      3844    0.048    0.000    0.066    0.000 sdm.py:285(to_list)
#      5770    0.048    0.000    0.048    0.000 colour.py:524(<listcomp>)
#      5770    0.048    0.000    0.119    0.000 colour.py:495(rgb2hex)
#      7688    0.048    0.000    0.069    0.000 symbol.py:254(_sanitize)
#     94178    0.048    0.000    0.048    0.000 expr.py:149(_hashable_content)
#       961    0.047    0.000   32.119    0.033 vector_field.py:88(pos_to_rgb)
#     14430    0.047    0.000    0.235    0.000 fromnumeric.py:2836(min)
#     30752    0.047    0.000    0.219    0.000 basic.py:428(__ne__)
#      9619    0.047    0.000    0.047    0.000 color.py:483(<listcomp>)
#     30752    0.047    0.000    0.093    0.000 {method 'setdefault' of 'dict' objects}
#      8644    0.046    0.000    0.253    0.000 arc.py:256(get_start)
# 8654/5771    0.045    0.000    0.930    0.000 vectorized_mobject.py:218(set_fill)
#     17298    0.045    0.000    0.045    0.000 libintmath.py:138(small_numeral)
#     49972    0.045    0.000    0.045    0.000 libmpf.py:692(mpf_sign)
#      1924    0.044    0.000    2.227    0.001 mobject.py:94(__init__)
#      5766    0.044    0.000    1.455    0.000 str.py:364(<listcomp>)
#      5766    0.044    0.000    0.086    0.000 matrices.py:1098(<listcomp>)
#      1922    0.043    0.000    1.583    0.001 common.py:1236(_eval_atoms)
#      9614    0.043    0.000    0.043    0.000 {built-in method numpy.arange}
#      2887    0.043    0.000    0.503    0.000 vectorized_mobject.py:757(add_line_to)
#      5766    0.043    0.000    0.129    0.000 libmpf.py:410(from_float)
#     23064    0.043    0.000    0.043    0.000 {built-in method builtins.round}
#      8645    0.043    0.000    0.216    0.000 arc.py:250(get_end)
#     14430    0.043    0.000    0.187    0.000 fromnumeric.py:2692(max)
#     13464    0.042    0.000    0.374    0.000 colour.py:1054(set_rgb)
#     17298    0.042    0.000    0.042    0.000 basic.py:2021(<genexpr>)
#      1921    0.042    0.000    2.845    0.001 vectorized_mobject.py:1260(point_from_proportion)
#      9612    0.042    0.000    0.229    0.000 mobject.py:2172(family_members_with_points)
#      9610    0.042    0.000    0.171    0.000 numbers.py:1219(num)
#      7694    0.042    0.000    0.042    0.000 colour.py:570(<listcomp>)
#      1922    0.041    0.000    9.732    0.005 lambdify.py:956(_recursive_to_string)
#      5766    0.041    0.000    0.526    0.000 latex.py:893(_hprint_Function)
#      9610    0.041    0.000    0.049    0.000 codeprinter.py:408(_print_Symbol)
#         1    0.041    0.041   75.433   75.433 vector_field.py:596(<listcomp>)
#      5766    0.040    0.000    0.066    0.000 basic.py:36(_old_compare)
#     85410    0.040    0.000    0.040    0.000 {built-in method builtins.issubclass}
#      7688    0.040    0.000    0.084    0.000 numbers.py:1872(__eq__)
#     11548    0.040    0.000    0.144    0.000 vectorized_mobject.py:773(<genexpr>)
#      5766    0.040    0.000    2.070    0.000 mul.py:813(as_coeff_mul)
#      1924    0.040    0.000    1.294    0.001 vectorized_mobject.py:145(init_colors)
#     11526    0.039    0.000    0.058    0.000 vectorized_mobject.py:1099(get_nth_curve_points)
#      5766    0.039    0.000    1.935    0.000 codeprinter.py:555(<listcomp>)
#      1922    0.039    0.000    0.079    0.000 latex.py:171(__init__)
#      9605    0.039    0.000    0.108    0.000 mobject.py:2033(get_start)
# 7688/1922    0.039    0.000    7.937    0.004 str.py:231(_print_list)
#     11532    0.038    0.000    0.044    0.000 str.py:676(_print_Integer)
#     28773    0.038    0.000    0.038    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     22097    0.038    0.000    0.106    0.000 mobject.py:2751(throw_error_if_no_points)
#     11526    0.038    0.000    0.117    0.000 vectorized_mobject.py:1116(get_nth_curve_function)
#     23064    0.038    0.000    0.696    0.000 vector.py:593(<genexpr>)
#     28830    0.038    0.000    0.046    0.000 basic.py:556(<listcomp>)
#     32674    0.037    0.000    0.037    0.000 numbers.py:1272(__bool__)
#     26908    0.037    0.000    0.037    0.000 sympify.py:17(__init__)
#      1924    0.037    0.000    2.428    0.001 vectorized_mobject.py:82(__init__)
#      5766    0.037    0.000    0.409    0.000 numpy.py:209(_print_Pow)
#     17298    0.037    0.000    0.044    0.000 exponential.py:211(__instancecheck__)
#     17298    0.036    0.000    0.082    0.000 libintmath.py:149(numeral_python)
#     11532    0.036    0.000    0.265    0.000 sdm.py:178(new)
#     24036    0.036    0.000    0.036    0.000 {built-in method numpy.asanyarray}
#     17298    0.036    0.000    0.036    0.000 {method 'mro' of 'type' objects}
#     23064    0.036    0.000    0.036    0.000 colour.py:478(_hue2rgb)
#      3844    0.035    0.000    0.139    0.000 mul.py:2122(_keep_coeff)
#      5766    0.034    0.000    0.263    0.000 numbers.py:3424(__eq__)
#      1922    0.034    0.000    0.107    0.000 lambdify.py:1097(__init__)
#     34596    0.034    0.000    0.034    0.000 {method 'find' of 'str' objects}
#      3844    0.034    0.000    0.302    0.000 codeprinter.py:426(_print_Function)
#      7684    0.034    0.000    0.445    0.000 mobject.py:2043(get_start_and_end)
#     24986    0.034    0.000    0.034    0.000 libmpf.py:663(mpf_neg)
#      7688    0.034    0.000    0.065    0.000 containers.py:52(__new__)
#     11532    0.033    0.000    0.059    0.000 operations.py:429(make_args)
#     11532    0.033    0.000    0.118    0.000 operations.py:125(_new_rawargs)
#      2885    0.033    0.000    0.421    0.000 vectorized_mobject.py:457(<listcomp>)
#      2882    0.033    0.000    1.257    0.000 vectorized_mobject.py:937(rotate)
#      3844    0.032    0.000    0.032    0.000 {method 'translate' of 'str' objects}
#     22097    0.032    0.000    0.068    0.000 mobject.py:2073(has_no_points)
#     17298    0.032    0.000    0.053    0.000 latex.py:532(<lambda>)
#     17298    0.032    0.000    0.032    0.000 libmpf.py:509(to_fixed)
#      5782    0.032    0.000    0.075    0.000 mobject.py:1845(reduce_across_dimension)
#      9610    0.031    0.000    2.305    0.000 assumptions.py:481(copy)
#      7688    0.031    0.000    0.031    0.000 {built-in method _abc._abc_instancecheck}
#      9610    0.031    0.000    0.067    0.000 codeprinter.py:135(_handle_assign_to)
#     23077    0.030    0.000    0.030    0.000 iterables.py:189(<listcomp>)
#       961    0.030    0.000    2.213    0.002 polygram.py:343(__init__)
#       961    0.030    0.000    3.612    0.004 arc.py:130(get_unpositioned_tip)
#     30763    0.029    0.000    0.029    0.000 {method 'split' of 'str' objects}
#      5763    0.029    0.000    0.112    0.000 fromnumeric.py:2177(sum)
#      3844    0.029    0.000    0.056    0.000 logic.py:115(fuzzy_and)
# 7688/1922    0.029    0.000    7.926    0.004 str.py:40(stringify)
#      1922    0.029    0.000    8.185    0.004 numpy.py:237(_print_MatrixBase)
#      1922    0.029    0.000    0.029    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#     13464    0.028    0.000    0.049    0.000 colour.py:1051(set_hsl)
#     34596    0.028    0.000    0.028    0.000 power.py:391(exp)
#      1921    0.028    0.000    0.404    0.000 line.py:598(_set_stroke_width_from_length)
#      5766    0.028    0.000    0.666    0.000 common.py:2276(<lambda>)
#     11532    0.028    0.000    7.906    0.001 common.py:2441(<lambda>)
#      7684    0.028    0.000    2.723    0.000 vectorized_mobject.py:1239(get_curve_functions_with_lengths)
#      5766    0.028    0.000    0.258    0.000 latex.py:1620(_print_Symbol)
#      7688    0.027    0.000    0.099    0.000 numbers.py:2083(_as_mpf_val)
#      7684    0.027    0.000    0.074    0.000 mobject.py:2038(get_end)
#     28772    0.027    0.000    0.038    0.000 linalg.py:140(isComplexType)
#       962    0.027    0.000    1.732    0.002 polygram.py:68(__init__)
#     22097    0.027    0.000    0.036    0.000 mobject.py:2069(has_points)
#     46128    0.027    0.000    0.027    0.000 boolalg.py:460(<lambda>)
#      1924    0.026    0.000    0.332    0.000 vectorized_mobject.py:421(<listcomp>)
# 7688/1922    0.026    0.000    7.915    0.004 str.py:41(<listcomp>)
#      1922    0.026    0.000    0.343    0.000 basic.py:991(<listcomp>)
#     11532    0.026    0.000    0.034    0.000 misc.py:501(as_int)
#      7688    0.026    0.000    0.052    0.000 basic.py:974(sympify_old)
#      7694    0.026    0.000    0.646    0.000 colour.py:1083(set_web)
#    1923/1    0.025    0.000   75.870   75.870 {built-in method builtins.exec}
#     39414    0.025    0.000    0.028    0.000 {method 'add' of 'set' objects}
#     11532    0.025    0.000    0.034    0.000 printer.py:324(<genexpr>)
#      7694    0.025    0.000    0.364    0.000 colour.py:1078(set_hex)
#      5770    0.025    0.000    0.025    0.000 colour.py:679(<listcomp>)
#      9611    0.025    0.000    0.025    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     25009    0.025    0.000    0.207    0.000 {built-in method builtins.setattr}
#     11532    0.024    0.000    0.024    0.000 libmpf.py:537(mpf_eq)
#      9612    0.024    0.000    0.040    0.000 mobject.py:2173(<listcomp>)
#       961    0.024    0.000    0.212    0.000 vectorized_mobject.py:465(get_color)
#     11532    0.024    0.000    7.878    0.001 basic.py:1168(xreplace)
#      7688    0.024    0.000    0.138    0.000 numbers.py:674(_as_mpf_op)
#     19220    0.024    0.000    0.024    0.000 logic.py:92(fuzzy_bool)
#     17298    0.024    0.000    0.024    0.000 printer.py:283(order)
#       960    0.024    0.000    0.143    0.000 space_ops.py:327(angle_between_vectors)
#         1    0.023    0.023    0.024    0.024 camera.py:237(init_background)
#      1922    0.023    0.000    1.611    0.001 common.py:1317(atoms)
#     11532    0.023    0.000    0.632    0.000 domainmatrix.py:472(to_sympy)
#      3844    0.023    0.000    0.023    0.000 textwrap.py:115(__init__)
#     13463    0.023    0.000    0.023    0.000 colour.py:346(<listcomp>)
#      3844    0.023    0.000    0.168    0.000 textwrap.py:160(_split)
#      3844    0.023    0.000    0.328    0.000 repmatrix.py:157(_eval_tolist)
#      5766    0.023    0.000    0.343    0.000 latex.py:942(<listcomp>)
#       961    0.023    0.000    0.053    0.000 space_ops.py:736(cartesian_to_spherical)
#      2887    0.023    0.000    0.110    0.000 vectorized_mobject.py:699(add_cubic_bezier_curve_to)
#       961    0.023    0.000    0.081    0.000 line.py:77(_set_start_and_end_attrs)
#      9610    0.023    0.000    0.038    0.000 ctx_mp_python.py:100(mpf_convert_rhs)
#      2885    0.023    0.000    0.913    0.000 vectorized_mobject.py:376(set_color)
#      5766    0.023    0.000    0.039    0.000 libmpf.py:64(dps_to_prec)
#       961    0.023    0.000    0.222    0.000 vectorized_mobject.py:844(set_points_as_corners)
#       961    0.022    0.000    0.026    0.000 vectorized_mobject.py:632(set_anchors_and_handles)
#      3844    0.022    0.000    0.355    0.000 common.py:629(tolist)
#     23064    0.022    0.000    0.031    0.000 operations.py:63(<genexpr>)
#      5766    0.022    0.000    0.032    0.000 numbers.py:2164(__add__)
#      7688    0.022    0.000    0.266    0.000 basic.py:984(sympify_new)
#      5766    0.022    0.000   10.843    0.002 common.py:1968(applyfunc)
#      1922    0.022    0.000    8.582    0.004 latex.py:2929(latex)
#     11532    0.022    0.000    2.827    0.000 vector.py:547(<genexpr>)
#      3844    0.022    0.000    0.043    0.000 symbol.py:377(sort_key)
#      3844    0.022    0.000    0.258    0.000 codeprinter.py:570(_print_not_supported)
#      2882    0.022    0.000    0.405    0.000 vectorized_mobject.py:500(rotate_sheen_direction)
#      4805    0.021    0.000    0.068    0.000 vectorized_mobject.py:865(<genexpr>)
#      2889    0.021    0.000    0.902    0.000 mobject.py:1474(rescale_to_fit)
#      3844    0.021    0.000    0.042    0.000 symbol.py:361(_hashable_content)
#     23077    0.021    0.000    0.021    0.000 vectorized_mobject.py:183(<listcomp>)
#     30752    0.021    0.000    0.021    0.000 {method 'extend' of 'list' objects}
#      1922    0.021    0.000    0.044    0.000 iterables.py:57(flatten)
#      5766    0.021    0.000    0.035    0.000 {method 'difference' of 'set' objects}
#     38440    0.021    0.000    0.021    0.000 {method 'keys' of 'dict' objects}
#      5766    0.020    0.000    0.023    0.000 power.py:962(as_base_exp)
#      2882    0.020    0.000    0.819    0.000 mobject.py:1217(rotate)
#      3849    0.020    0.000    0.091    0.000 vectorized_mobject.py:669(append_points)
#     11532    0.020    0.000    0.029    0.000 containers.py:70(__iter__)
#       960    0.020    0.000    1.504    0.002 line.py:117(put_start_and_end_on)
#      1922    0.020    0.000    0.202    0.000 textwrap.py:381(fill)
#     23077    0.020    0.000    0.020    0.000 vectorized_mobject.py:571(get_sheen_factor)
#      5766    0.020    0.000    0.085    0.000 basic.py:240(compare)
#      5766    0.020    0.000    0.027    0.000 numbers.py:2225(__mod__)
#      1922    0.020    0.000    1.635    0.001 vector.py:281(to_matrix)
#     19220    0.020    0.000    0.020    0.000 numbers.py:3147(__neg__)
#      5766    0.020    0.000    0.020    0.000 {built-in method math.frexp}
#      9610    0.019    0.000    0.029    0.000 assumptions.py:484(generator)
#      9610    0.019    0.000    0.163    0.000 ctx_mp_python.py:179(__lt__)
#      3844    0.019    0.000    0.242    0.000 symbol.py:285(__new__)
#       961    0.019    0.000    0.035    0.000 space_ops.py:304(angle_of_vector)
#      3844    0.019    0.000    0.082    0.000 codeprinter.py:109(__init__)
#     42284    0.019    0.000    0.019    0.000 boolalg.py:420(__bool__)
#      5766    0.019    0.000    0.102    0.000 numbers.py:2253(__gt__)
#      1926    0.019    0.000    0.019    0.000 mobject.py:1251(func)
#      5766    0.019    0.000    0.070    0.000 mul.py:653(<listcomp>)
#     11526    0.019    0.000    0.021    0.000 bezier.py:34(bezier)
#     11532    0.019    0.000    0.019    0.000 {method 'splitlines' of 'str' objects}
#      3844    0.019    0.000    0.404    0.000 textwrap.py:342(wrap)
#      3844    0.019    0.000    0.024    0.000 matrices.py:774(__len__)
#     11532    0.019    0.000    0.019    0.000 {method 'index' of 'list' objects}
#     23077    0.018    0.000    0.018    0.000 iterables.py:190(<listcomp>)
#     13447    0.018    0.000    0.022    0.000 vectorized_mobject.py:1212(get_num_curves)
#       961    0.018    0.000    0.265    0.000 space_ops.py:412(compass_directions)
#       960    0.018    0.000    0.387    0.000 line.py:514(scale)
#      3844    0.018    0.000    0.261    0.000 symbol.py:64(_symbol)
#      3844    0.018    0.000    0.056    0.000 textwrap.py:146(_munge_whitespace)
#      7697    0.018    0.000    0.018    0.000 {built-in method numpy.zeros}
#      5766    0.018    0.000    0.270    0.000 numbers.py:1959(__lt__)
#     34535    0.018    0.000    0.018    0.000 linalg.py:2379(_norm_dispatcher)
#     17298    0.018    0.000    0.018    0.000 numbers.py:1202(_hashable_content)
#     44206    0.018    0.000    0.018    0.000 traversal.py:165(__iter__)
#      5766    0.018    0.000    0.253    0.000 latex.py:759(<lambda>)
#      7688    0.017    0.000    0.021    0.000 lambdify.py:933(_module_present)
#     15376    0.017    0.000    0.021    0.000 repmatrix.py:104(<genexpr>)
#     15376    0.017    0.000    0.021    0.000 repmatrix.py:119(<genexpr>)
#      5766    0.017    0.000    0.058    0.000 mul.py:478(<listcomp>)
#      3844    0.017    0.000    0.333    0.000 sorting.py:141(<listcomp>)
#      5766    0.017    0.000    0.198    0.000 numbers.py:3590(__eq__)
#     39250    0.017    0.000    0.017    0.000 {built-in method numpy.asarray}
#       961    0.017    0.000    3.164    0.003 tips.py:228(__init__)
#       961    0.016    0.000    0.016    0.000 _methods.py:90(_clip)
#      5766    0.016    0.000    2.409    0.000 basisdependent.py:27(__add__)
#      1921    0.016    0.000    0.016    0.000 mobject.py:1209(<lambda>)
#      9610    0.016    0.000    0.026    0.000 codeprinter.py:38(_convert_python_lists)
#       961    0.016    0.000   10.976    0.011 line.py:495(__init__)
#      5766    0.016    0.000    0.016    0.000 {built-in method _bisect.bisect_right}
#     23077    0.016    0.000    0.016    0.000 vectorized_mobject.py:184(<listcomp>)
#      7688    0.016    0.000    0.097    0.000 domainmatrix.py:668(to_list_flat)
#     17298    0.016    0.000    0.025    0.000 latex.py:568(<genexpr>)
#       961    0.016    0.000    0.436    0.000 space_ops.py:431(regular_vertices)
#      3967    0.016    0.000    0.016    0.000 {method 'replace' of 'str' objects}
#     19220    0.016    0.000    0.016    0.000 {method 'pop' of 'list' objects}
#      7688    0.015    0.000    0.040    0.000 matrices.py:998(<genexpr>)
#      1922    0.015    0.000    0.567    0.000 basisdependent.py:277(<listcomp>)
#      9605    0.015    0.000    0.100    0.000 arc.py:201(has_tip)
#      9620    0.015    0.000    0.169    0.000 vectorized_mobject.py:1411(<genexpr>)
#       961    0.015    0.000    0.452    0.000 polygram.py:371(gen_polygon_vertices)
#      1922    0.015    0.000    0.323    0.000 basic.py:994(<listcomp>)
#      7688    0.015    0.000    0.094    0.000 containers.py:108(__hash__)
#      3844    0.015    0.000    0.239    0.000 textwrap.py:336(_split_chunks)
#      7688    0.015    0.000    0.046    0.000 abc.py:117(__instancecheck__)
#      1922    0.015    0.000    0.885    0.000 vector.py:307(<listcomp>)
#     17299    0.014    0.000    0.014    0.000 {method 'rstrip' of 'str' objects}
#      1922    0.014    0.000    0.269    0.000 textwrap.py:368(wrap)
#      1922    0.014    0.000    0.028    0.000 matrices.py:1000(<listcomp>)
#     11532    0.014    0.000    0.420    0.000 sorting.py:195(<genexpr>)
#      5766    0.014    0.000    0.135    0.000 mul.py:33(_mulsort)
#     19220    0.014    0.000    0.014    0.000 scalar.py:68(_sympystr)
#      2891    0.014    0.000    0.089    0.000 mobject.py:2010(length_over_dim)
#      4809    0.014    0.000    0.088    0.000 {method 'any' of 'numpy.ndarray' objects}
#     15376    0.014    0.000    0.016    0.000 operations.py:121(<genexpr>)
#       961    0.014    0.000    1.381    0.001 line.py:36(__init__)
#     13463    0.013    0.000    0.013    0.000 colour.py:1014(get_hsl)
#      2881    0.013    0.000    0.064    0.000 fromnumeric.py:2421(all)
#     17298    0.013    0.000    0.013    0.000 str.py:272(<genexpr>)
#       961    0.013    0.000    3.036    0.003 arc.py:181(reset_endpoints_based_on_tip)
#      5766    0.013    0.000    4.562    0.001 vector.py:545(<genexpr>)
#     15238    0.013    0.000    0.013    0.000 {method 'insert' of 'list' objects}
#      3844    0.013    0.000    9.504    0.002 common.py:2426(xreplace)
#       961    0.013    0.000    9.382    0.010 arc.py:104(add_tip)
#      3844    0.013    0.000    0.163    0.000 expr.py:220(__rmul__)
#      3844    0.013    0.000    0.013    0.000 sdm.py:303(<listcomp>)
#      3844    0.012    0.000    0.019    0.000 lambdify.py:1178(_is_safe_ident)
#       961    0.012    0.000   10.990    0.011 line.py:639(__init__)
#     10586    0.012    0.000    0.012    0.000 vectorized_mobject.py:828(get_last_point)
#      2885    0.012    0.000    0.436    0.000 vectorized_mobject.py:456(get_stroke_colors)
#      9604    0.012    0.000    0.115    0.000 arc.py:204(has_start_tip)
#      5766    0.012    0.000    0.026    0.000 matrices.py:985(make_explicit_row)
#      3844    0.012    0.000    0.078    0.000 domainmatrix.py:665(to_list)
#     11256    0.012    0.000    0.018    0.000 numeric.py:1380(<listcomp>)
#      3844    0.012    0.000    0.020    0.000 lambdify.py:941(_get_namespace)
#      5766    0.012    0.000    0.012    0.000 operations.py:91(<listcomp>)
#      5766    0.012    0.000    0.028    0.000 libintmath.py:91(python_bitcount)
#     10573    0.012    0.000    0.016    0.000 mobject.py:1900(get_num_points)
#       961    0.012    0.000    2.224    0.002 polygram.py:427(__init__)
#      9611    0.012    0.000    0.017    0.000 numeric.py:1855(isscalar)
#       961    0.012    0.000    0.012    0.000 bezier.py:270(inverse_interpolate)
#      1924    0.012    0.000    0.180    0.000 vectorized_mobject.py:295(set_background_stroke)
#      9611    0.012    0.000    0.012    0.000 fromnumeric.py:3176(ndim)
#      3844    0.012    0.000    0.212    0.000 {built-in method builtins.repr}
#     11532    0.011    0.000    0.011    0.000 numbers.py:2039(as_coeff_Mul)
#      1921    0.011    0.000    0.376    0.000 mobject.py:1167(scale)
#     25008    0.011    0.000    0.011    0.000 {method 'reverse' of 'list' objects}
#      7688    0.011    0.000    0.022    0.000 pycode.py:138(_get_comment)
#     17298    0.011    0.000    0.011    0.000 {built-in method builtins.abs}
#     19220    0.011    0.000    0.011    0.000 {method 'values' of 'dict' objects}
#       961    0.011    0.000    0.015    0.000 function_base.py:1606(angle)
#      3844    0.011    0.000    0.162    0.000 symbol.py:344(__xnew_cached_)
#     16884    0.010    0.000    0.010    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#      3844    0.010    0.000    0.226    0.000 str.py:43(emptyPrinter)
#     17298    0.010    0.000    0.010    0.000 {built-in method from_iterable}
#      4811    0.010    0.000    0.010    0.000 vectorized_mobject.py:1374(get_start_anchors)
#      1921    0.010    0.000    2.855    0.001 tips.py:101(base)
#       961    0.010    0.000    3.174    0.003 tips.py:256(__init__)
#     11532    0.010    0.000    0.010    0.000 numbers.py:3203(__neg__)
#      5766    0.010    0.000    0.010    0.000 lambdify.py:911(<genexpr>)
#       960    0.010    0.000    0.010    0.000 simple_functions.py:137(sigmoid)
#     21143    0.010    0.000    0.010    0.000 {built-in method builtins.callable}
#      1922    0.009    0.000    0.193    0.000 line.py:583(get_default_tip_length)
#      7688    0.009    0.000    0.009    0.000 basisdependent.py:318(__hash__)
#       961    0.009    0.000    0.026    0.000 {method 'clip' of 'numpy.generic' objects}
#      1922    0.009    0.000    0.036    0.000 matrices.py:993(<listcomp>)
#       961    0.009    0.000    0.048    0.000 vector_field.py:82(color_scheme)
#      4810    0.009    0.000    0.009    0.000 vectorized_mobject.py:1384(get_end_anchors)
#       961    0.009    0.000    6.311    0.007 arc.py:120(create_tip)
#     13454    0.009    0.000    0.009    0.000 immutable.py:54(rows)
#      1924    0.009    0.000    0.017    0.000 vectorized_mobject.py:531(set_sheen)
#      2885    0.009    0.000    0.445    0.000 vectorized_mobject.py:439(get_stroke_color)
#       963    0.009    0.000    0.024    0.000 mobject.py:358(add)
#      1922    0.009    0.000    5.625    0.003 vector.py:137(cross)
#       962    0.009    0.000    0.511    0.001 vectorized_mobject.py:839(add_points_as_corners)
#      5628    0.009    0.000    0.009    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#     11532    0.009    0.000    0.009    0.000 power.py:387(base)
#     11532    0.009    0.000    0.009    0.000 vector.py:389(system)
#       961    0.009    0.000    1.286    0.001 arc.py:90(__init__)
#      1922    0.008    0.000    8.481    0.004 latex.py:263(doprint)
#      3844    0.008    0.000    0.008    0.000 textwrap.py:179(<listcomp>)
#       961    0.008    0.000    0.239    0.000 space_ops.py:428(<listcomp>)
#      5766    0.008    0.000    0.018    0.000 matrices.py:970(<lambda>)
#      5766    0.008    0.000    0.008    0.000 symbol.py:201(<genexpr>)
#      1924    0.008    0.000    0.342    0.000 vectorized_mobject.py:420(get_fill_colors)
#      3844    0.008    0.000    0.022    0.000 line.py:89(_pointify)
#      1922    0.008    0.000    0.168    0.000 textwrap.py:356(fill)
#      9610    0.008    0.000    0.008    0.000 str.py:845(_print_Symbol)
#      3844    0.008    0.000    0.008    0.000 {method 'union' of 'set' objects}
#      7688    0.008    0.000    0.008    0.000 libmpf.py:208(_normalize1)
#       961    0.008    0.000   32.296    0.034 vector_field.py:107(<lambda>)
#      4809    0.008    0.000    0.074    0.000 _methods.py:55(_any)
#      5766    0.008    0.000    0.011    0.000 matrices.py:976(make_explicit)
#      5766    0.008    0.000    0.008    0.000 numbers.py:1269(_eval_is_zero)
#      1922    0.008    0.000    0.729    0.000 immutable.py:42(__new__)
#       961    0.008    0.000    0.230    0.000 line.py:51(set_points_by_ends)
#     11532    0.008    0.000    0.008    0.000 latex.py:1636(<listcomp>)
#      1924    0.008    0.000    0.008    0.000 utils.py:1213(renderer)
#      7688    0.008    0.000    0.008    0.000 coordsysrect.py:451(base_vectors)
#       961    0.007    0.000    1.461    0.002 tips.py:135(vector)
#       961    0.007    0.000    2.232    0.002 polygram.py:558(__init__)
#     11532    0.007    0.000    0.007    0.000 {method 'strip' of 'str' objects}
#     13454    0.007    0.000    0.007    0.000 immutable.py:50(cols)
#      1926    0.007    0.000    0.480    0.000 mobject.py:1250(stretch)
#       961    0.007    0.000    0.169    0.000 color.py:467(rgb_to_color)
#      1922    0.007    0.000    8.192    0.004 pycode.py:283(<lambda>)
#     14430    0.007    0.000    0.007    0.000 fromnumeric.py:2831(_min_dispatcher)
#      5766    0.007    0.000    0.007    0.000 numbers.py:3418(_as_mpf_val)
#      3844    0.007    0.000    0.010    0.000 symbol.py:373(assumptions0)
#      1922    0.007    0.000    0.007    0.000 lambdify.py:120(_import)
#     14430    0.006    0.000    0.006    0.000 fromnumeric.py:2687(_max_dispatcher)
#      5763    0.006    0.000    0.006    0.000 {method 'conj' of 'numpy.ndarray' objects}
#       962    0.006    0.000    0.035    0.000 vectorized_mobject.py:676(start_new_path)
#      1924    0.006    0.000    0.012    0.000 mobject.py:338(reset_points)
#      1922    0.006    0.000    1.357    0.001 common.py:2257(replace)
#      5766    0.006    0.000    0.006    0.000 expr.py:2009(as_base_exp)
#       961    0.006    0.000    0.358    0.000 mobject.py:1484(scale_to_fit_width)
#      3844    0.006    0.000    0.006    0.000 {method 'expandtabs' of 'str' objects}
#      3844    0.006    0.000    0.016    0.000 iterables.py:104(reducible)
#      5766    0.006    0.000    0.006    0.000 scalar.py:56(_latex)
#      5766    0.006    0.000    0.006    0.000 {method 'index' of 'tuple' objects}
#       961    0.006    0.000    1.502    0.002 tips.py:151(tip_angle)
#      2883    0.006    0.000    0.006    0.000 {built-in method _functools.reduce}
#      2887    0.006    0.000    0.006    0.000 vectorized_mobject.py:823(has_new_path_started)
#      5766    0.005    0.000    0.007    0.000 lambdify.py:1199(<genexpr>)
#      9611    0.005    0.000    0.005    0.000 fromnumeric.py:3172(_ndim_dispatcher)
#       961    0.005    0.000    0.037    0.000 fromnumeric.py:2100(clip)
#      1924    0.005    0.000    0.348    0.000 vectorized_mobject.py:404(get_fill_color)
#      1922    0.005    0.000    0.011    0.000 inspect.py:1548(currentframe)
#      1922    0.005    0.000    0.007    0.000 inspect.py:159(isfunction)
#      3844    0.005    0.000    0.005    0.000 {method 'isidentifier' of 'str' objects}
#      5766    0.005    0.000    0.005    0.000 {built-in method math.isnan}
#      9611    0.005    0.000    0.005    0.000 function_base.py:19(_linspace_dispatcher)
#     11532    0.005    0.000    0.005    0.000 latex.py:1637(<listcomp>)
#      5766    0.005    0.000    0.007    0.000 matrices.py:966(<lambda>)
#      9610    0.005    0.000    0.005    0.000 pycode.py:132(_format_code)
#       963    0.005    0.000    0.005    0.000 iterables.py:132(list_update)
#      5766    0.005    0.000    0.005    0.000 numbers.py:3584(_as_mpf_val)
#      5766    0.005    0.000    0.005    0.000 function.py:369(func)
#       960    0.004    0.000    0.014    0.000 vector_field.py:547(<lambda>)
#      1922    0.004    0.000    0.005    0.000 basisdependent.py:321(__eq__)
# ...
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2881>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2945>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3383>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3098>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3628>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3180>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3228>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3590>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3635>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2592>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2266>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3313>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2622>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2625>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2356>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3736>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2601>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2808>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2118>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2800>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2827>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2079>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2031>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2108>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2025>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2409>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2089>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3294>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1945>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2602>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3743>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2518>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2877>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2548>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2180>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2022>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2429>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2961>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2554>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2419>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2408>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2466>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3596>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2465>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3112>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2291>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2673>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1934>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1987>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2672>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2447>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2223>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2532>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2081>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2364>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2937>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2509>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3468>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3095>:1(<module>)
#         1    0.000    0.000    0.000    0.000 scene.py:681(add_safe_mobjects_from_list)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3026>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2109>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2697>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2934>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2028>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2686>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1972>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2259>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2952>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3090>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3587>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3653>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3459>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1937>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2013>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3507>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2083>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2140>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2584>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2045>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1930>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2346>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3659>:1(<module>)
#         2    0.000    0.000    0.000    0.000 utils.py:1042(<lambda>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3152>:1(<module>)
#         1    0.000    0.000    0.000    0.000 mobject.py:664(width)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2046>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2927>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3533>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3099>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3174>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2267>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3280>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2136>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2190>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2166>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1975>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2965>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1932>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1941>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3724>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3761>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2938>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2690>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2667>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2960>:1(<module>)
#         2    0.000    0.000    0.000    0.000 utils.py:1048(<lambda>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3603>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3612>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2831>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3229>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2255>:1(<module>)
#         2    0.000    0.000    0.000    0.000 os.py:740(check_str)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3525>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3502>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3560>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3498>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2967>:1(<module>)
#         1    0.000    0.000    0.000    0.000 shutil.py:1455(<listcomp>)
#         1    0.000    0.000    0.000    0.000 scene_file_writer.py:175(finish_last_section)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2624>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2130>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2962>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3745>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3276>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3019>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3475>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2365>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2841>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2313>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3610>:1(<module>)
#         1    0.000    0.000    0.000    0.000 ntpath.py:34(_get_bothseps)
#         1    0.000    0.000    0.000    0.000 os.py:771(getenv)
#         1    0.000    0.000    0.000    0.000 function_base.py:2453(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2001>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3528>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3120>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3614>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3476>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2072>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3834>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3637>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3638>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1943>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3531>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3543>:1(<module>)
#         2    0.000    0.000    0.000    0.000 utils.py:916(<lambda>)
#         1    0.000    0.000    0.000    0.000 utils.py:1145(<lambda>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2237>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3289>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3514>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3200>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3625>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3644>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1942>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3549>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3833>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2226>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 os.py:816(fsdecode)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3630>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2411>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3499>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2236>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3515>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2214>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2969>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3661>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3503>:1(<module>)
#         1    0.000    0.000    0.000    0.000 scene_file_writer.py:260(init_audio)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2489>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2229>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3731>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2386>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1962>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2752>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2446>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3145>:1(<module>)
#         1    0.000    0.000    0.000    0.000 utils.py:1283(<lambda>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-1970>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-3692>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2497>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <lambdifygenerated-2904>:1(<module>)
#         2    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:1025(<lambda>)
#         1    0.000    0.000    0.000    0.000 utils.py:1098(<lambda>)
#         2    0.000    0.000    0.000    0.000 pathlib.py:198(<listcomp>)
#         1    0.000    0.000    0.000    0.000 utils.py:1007(<lambda>)
#         1    0.000    0.000    0.000    0.000 utils.py:1155(<lambda>)
#         1    0.000    0.000    0.000    0.000 camera.py:136(background_color)
#         1    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISDIR}
#         1    0.000    0.000    0.000    0.000 utils.py:1558(<lambda>)
#         1    0.000    0.000    0.000    0.000 camera.py:145(background_opacity)
#         1    0.000    0.000    0.000    0.000 utils.py:1564(<lambda>)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1764(_ravel_dispatcher)
